# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# %matplotlib inline

# %%
#read csv document
df = pd.read_csv('2007-2016-Homelessnewss-USA.csv')

# %%
#explore the head
df.head()
# Out:
#        Year State CoC Number       CoC Name  \
# 0  1/1/2007    AK     AK-500  Anchorage CoC
# 1  1/1/2007    AK     AK-500  Anchorage CoC
# 2  1/1/2007    AK     AK-500  Anchorage CoC
# 3  1/1/2007    AK     AK-500  Anchorage CoC
# 4  1/1/2007    AK     AK-500  Anchorage CoC
#
#                                      Measures Count
# 0            Chronically Homeless Individuals   224
# 1                        Homeless Individuals   696
# 2                 Homeless People in Families   278
# 3  Sheltered Chronically Homeless Individuals   187
# 4                          Sheltered Homeless   842

# %%
#explore the tail
df.tail()
# Out:
#            Year State CoC Number               CoC Name  \
# 86524  1/1/2016    WY     WY-500  Wyoming Statewide CoC
# 86525  1/1/2016    WY     WY-500  Wyoming Statewide CoC
# 86526  1/1/2016    WY     WY-500  Wyoming Statewide CoC
# 86527  1/1/2016    WY     WY-500  Wyoming Statewide CoC
# 86528  1/1/2016    WY     WY-500  Wyoming Statewide CoC
#
#                                                 Measures Count
# 86524  Unsheltered Homeless Unaccompanied Youth (Unde...     7
# 86525                      Unsheltered Homeless Veterans    31
# 86526             Unsheltered Parenting Youth (Under 25)     3
# 86527              Unsheltered Parenting Youth Age 18-24     3
# 86528               Unsheltered Parenting Youth Under 18     0

# %%
#what are the types of data
df.dtypes
# Out:
# Year          object
# State         object
# CoC Number    object
# CoC Name      object
# Measures      object
# Count         object
# dtype: object

# %%
#change count to int/float

df['Count'] = df['Count'].str.replace(',','').astype(np.int64)

#change year to date
df['Year'] = pd.to_datetime(df['Year'])

# %%
#Check the data type 
df.dtypes
# Out:
# Year          datetime64[ns]
# State                 object
# CoC Number            object
# CoC Name              object
# Measures              object
# Count                  int64
# dtype: object

# %%
#copy a new data in a varible
newdf = df.copy()

# %%
newdf.head(2)
# Out:
#         Year State CoC Number       CoC Name  \
# 0 2007-01-01    AK     AK-500  Anchorage CoC
# 1 2007-01-01    AK     AK-500  Anchorage CoC
#
#                            Measures  Count
# 0  Chronically Homeless Individuals    224
# 1              Homeless Individuals    696

# %%
#Delete Coc Number and CoC Name
newdf.drop(['CoC Number','CoC Name'],axis=1 )
# Out:
#             Year State                                           Measures  \
# 0     2007-01-01    AK                   Chronically Homeless Individuals
# 1     2007-01-01    AK                               Homeless Individuals
# 2     2007-01-01    AK                        Homeless People in Families
# 3     2007-01-01    AK         Sheltered Chronically Homeless Individuals
# 4     2007-01-01    AK                                 Sheltered Homeless
# 5     2007-01-01    AK                     Sheltered Homeless Individuals
# 6     2007-01-01    AK              Sheltered Homeless People in Families
# 7     2007-01-01    AK                                     Total Homeless
# 8     2007-01-01    AK       Unsheltered Chronically Homeless Individuals
# 9     2007-01-01    AK                               Unsheltered Homeless
# 10    2007-01-01    AK                   Unsheltered Homeless Individuals
# 11    2007-01-01    AK            Unsheltered Homeless People in Families
# 12    2007-01-01    AK                   Chronically Homeless Individuals
# 13    2007-01-01    AK                               Homeless Individuals
# 14    2007-01-01    AK                        Homeless People in Families
# 15    2007-01-01    AK         Sheltered Chronically Homeless Individuals
# 86503      4
# 86504    491
# 86505    277
# 86506    214
# 86507      1
# 86508     23
# 86509     24
# 86510     56
# 86511     12
# 86512     12
# 86513      0
# 86514    857
# 86515      3
# 86516     58
# 86517     51
# 86518      7
# 86519    366
# 86520    240
# 86521    126
# 86522      2
# 86523      5
# 86524      7
# 86525     31
# 86526      3
# 86527      3
# 86528      0
#
# [86529 rows x 4 columns]

# %%
#plotting a car chart to see max number of homelessness according to state
newdf.State.value_counts().plot(kind='bar',title='Total number of homeless people according to states',figsize=(20,20), colormap= 'pink',fontsize=18)
plt.xlabel('States')
plt.ylabel('Number of people ')

# %%
#From the chart above we can see that California has most poplution that are homeless

# %%
newdf.Measures.value_counts()
# Out:
# Total Homeless                                                 3999
# Sheltered Homeless                                             3999
# Sheltered Homeless People in Families                          3999
# Sheltered Chronically Homeless Individuals                     3999
# Homeless Individuals                                           3999
# Sheltered Homeless Individuals                                 3999
# Unsheltered Homeless                                           3999
# Unsheltered Homeless People in Families                        3999
# Unsheltered Homeless Individuals                               3999
# Homeless People in Families                                    3999
# Unsheltered Chronically Homeless Individuals                   3999
# Chronically Homeless Individuals                               3999
# Sheltered Chronically Homeless People in Families              2404
# Homeless Veterans                                              2404
# Chronically Homeless                                           2404
# Chronically Homeless People in Families                        2404
# Sheltered Homeless Veterans                                    2404
# Unsheltered Chronically Homeless People in Families            2404
# Unsheltered Chronically Homeless                               2404
# Sheltered Chronically Homeless                                 2404
# Unsheltered Homeless Veterans                                  2404
# Homeless Unaccompanied Young Adults (Age 18-24)                 805
# Parenting Youth Under 18                                        805
# Parenting Youth (Under 25)                                      805
# Sheltered Parenting Youth (Under 25)                            805
# Homeless Unaccompanied Children (Under 18)                      805
# Unsheltered Parenting Youth (Under 25)                          805
# Parenting Youth Age 18-24                                       805
# Unsheltered Homeless Unaccompanied Children (Under 18)          805
# Unsheltered Parenting Youth Age 18-24                           805
# Unsheltered Homeless Unaccompanied Youth (Under 25)             805
# Children of Parenting Youth                                     805
# Homeless Unaccompanied Youth (Under 25)                         805
# Sheltered Homeless Unaccompanied Young Adults (Age 18-24)       805
# Sheltered Parenting Youth Under 18                              805
# Sheltered Children of Parenting Youth                           805
# Unsheltered Homeless Unaccompanied Young Adults (Age 18-24)     805
# Sheltered Parenting Youth Age 18-24                             805
# Unsheltered Children of Parenting Youth                         805
# Unsheltered Parenting Youth Under 18                            805
# Sheltered Homeless Unaccompanied Youth (Under 25)               805
# Sheltered Homeless Unaccompanied Children (Under 18)            805
# Name: Measures, dtype: int64

# %%
newdf.Measures.value_counts().plot(kind='bar',title='Meseasures of homelessness ',figsize=(20,20),colormap= 'pink',fontsize=18)
plt.xlabel('Measures')
plt.ylabel('Number of people ')

# %%
newdf.Year.value_counts().plot('bar',colormap= 'pink',figsize=(20,20),fontsize=18)

# %%
# we can see from the chart above that most people were homeless on 2015.

# %%
#exploring DC
explr_dc = newdf[newdf['State']=='DC']

explr_dc.groupby(['Year', 'Measures']).sum().unstack().plot.bar(stacked = True,title='Years with measures', colormap= 'Dark2',figsize=(30,30),fontsize=24)

# %%
#total number of people in DC who were homeless
explr_dc['Count'].sum()
# Out:
# 349688
